# %%
import numpy as np
# loaded_array1 = np.load('C:/Users/hennecol/Documents/FMRI experiment/FINAL FOLDER/Lucas/MindBridge/data/natural-scenes-dataset/webdataset_avg_split/train/subj13/sample000000000.coco73k.npy')
loaded_array1 = np.load(r"E:\MiB\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\train\subj07\sample000000301.coco73k.npy")


# [2950] (1,) sample id?
print("coco73k.npy :", loaded_array1.shape, loaded_array1)


# loaded_array2 = np.load(r"Z:\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\train\subj0132\sample0000000060.nsdgeneral.npy")
loaded_array2 = np.load(r"E:\MiB\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\train\subj0134\sample0000000060.nsdgeneral.npy")

print("nsdgeneral.npy2 :", loaded_array2.shape, loaded_array2)

# loaded_array6 = np.load(r"Z:\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\train\subj0133\sample0000000060.nsdgeneral.npy")
loaded_array6 = np.load(r"E:\MiB\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\train\subj0134\sample0000000060.nsdgeneral.npy")

print("nsdgeneral.npy2 :", loaded_array6.shape, loaded_array6)
# Vérifier si les tableaux sont égaux
arrays_are_equal = np.array_equal(loaded_array2, loaded_array6)

# Afficher le résultat
print("Les tableaux sont-ils égaux?", arrays_are_equal)


arrays_are_close = np.allclose(loaded_array2, loaded_array6)

print("Les tableaux sont-ils proches?", arrays_are_close)


# loaded_array3 = np.load('C:/Users/hennecol/Documents/FMRI experiment/FINAL FOLDER/Lucas/MindBridge/data/natural-scenes-dataset/webdataset_avg_split/val/subj02/sample000000001.num_uniques.npy')
loaded_array3 = np.load(r"E:\MiB\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\val\subj02\sample000000001.num_uniques.npy")
#[3] (1,) dimension ou nombre de fois qu'a ete montree l'image?
#print("num_uniques.npy :", loaded_array3.shape, loaded_array3)

# loaded_array4 = np.load('C:/Users/hennecol/Documents/FMRI experiment/FINAL FOLDER/Lucas/MindBridge/data/natural-scenes-dataset/webdataset_avg_split/val/subj02/sample000000001.trial.npy')
loaded_array4 = np.load(r"E:\MiB\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\val\subj02\sample000000001.trial.npy")

#[2615] (1,) idk
#print("trial.npy :", loaded_array4.shape, loaded_array4)

# loaded_array5 = np.load('C:/Users/hennecol/Documents/FMRI experiment/FINAL FOLDER/Lucas/MindBridge/data/natural-scenes-dataset/webdataset_avg_split/val/subj02/sample000000001.wholebrain_3d.npy')
loaded_array5 = np.load(r"E:\MiB\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\val\subj02\sample000000001.wholebrain_3d.npy")

#(3, 81, 104, 83) all brain voxels in 3d
#print("wholebrain_3d.npy :", loaded_array5.shape, loaded_array5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 # loaded_array1 = np.load('C:/Users/hennecol/Documents/FMRI experiment/FINAL FOLDER/Lucas/MindBridge/data/natural-scenes-dataset/webdataset_avg_split/train/subj13/sample000000000.coco73k.npy')
# ----> 3 loaded_array1 = np.load(r"E:\MiB\MindBridge\data\natural-scenes-dataset\webdataset_avg_split\train\subj07\sample000000301.coco73k.npy")
#       6 # [2950] (1,) sample id?
#       7 print("coco73k.npy :", loaded_array1.shape, loaded_array1)
#
# File c:\Users\Rémi\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
# ...

# %%
import matplotlib.pyplot as plt

# Visualiser chaque ligne
for i in range(loaded_array2.shape[0]):
    plt.plot(loaded_array2[i][100:150], label=f'Ligne {i+1}')
plt.legend()
plt.title('Visualisation des z-scores')
plt.show()

# %%
# Calculer la matrice de corrélation entre les lignes
correlation_matrix = np.corrcoef(loaded_array2)
print("Correlation matrix:\n", correlation_matrix)
# Out:
# Correlation matrix:
#  [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
import json

# Charger le fichier JSON
# with open('Z:/MindBridge/data/natural-scenes-dataset/nsddata_stimuli/stimuli/nsd/annotations/captions_train2017.json', 'r', encoding='utf-8') as file:
with open(r"E:\MiB\MindBridge\data\natural-scenes-dataset\nsddata_stimuli\stimuli\nsd\annotations\captions_train2017.json", 'r', encoding='utf-8') as file:

    data = json.load(file)

# Récupérer toutes les données ["annotations"]["id"]
annotations_ids = [annotation['id'] for annotation in data['annotations']]

print(max(annotations_ids))
# Out:
# 1000827
